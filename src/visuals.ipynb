# %% [markdown]
# # Evaluation of Syllabifier 1.0

# %% [markdown]
# *Visual evaluation of the automatic syllabifier, using Altair*

# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# We load the original training set of 20139 sylabified words from Bouma en Hermans. This list of words is organized alphabetically and runs up until the word 'kerstauonde'; i.e. words starting in the range L-Z ar not part of the training data!

# %%
bouma_hermans = {w.replace('-','').strip() for w in open('../data/crm.txt')}

# %% [markdown]
# Next, we load the new data set, which is a sample of 2000 words taken from the Corpus of Middle Dutch rhymed texts. This sample will serve as an evaluation of the predictions made by the syllabifier. We expect that mistakes will be made with regard to words in the range L-Z.

# %%
new = {w.replace('-', '').strip() for w in open('../data/syllabified_sample_words_1.txt')}

# %% [markdown]
# Before we will evaluate the model, we want to know the overlap (or: intersection) of words between both data sets.

# %%
intersection = bouma_hermans.intersection(new)
print('The overlap is', len(intersection), "words.")
# Out:
# The overlap is 117 words.

# %% [markdown]
# After manually checking the predictions for the 2000-word sample, we get an idea of how well the syllabifier performs on new, unseen data. The column below shows for each letter in the alphabet how many predictions are correct (True) and how many are incorrect (False).

# %%
df = pd.read_excel('../data/evaluation_syllabifier.xlsx')
df['correction'] = (df['syllabifier'] == df['manual_syllabification'])
df['alphabet'] = df['word'].astype(str).str[0]

x = df.groupby('alphabet').correction.value_counts().to_frame()
x.columns = ['counts']
x = x.reset_index()
x
# Out:
#    alphabet  correction  counts
# 0         a        True      93
# 1         a       False       6
# 2         b        True     134
# 3         b       False       3
# 4         c        True     101
# 5         c       False       9
# 6         d        True     107
# 7         d       False       7
# 8         e        True      48
# 9         e       False       2
# 10        f        True      16
# 11        g        True     228
# 12        g       False       8
# 13        h        True      85
# 14        h       False       3
# 15        i        True      19
# 16        i       False       2
# 17        j        True      20
# 18        j       False       2
# 19        k        True      31
# 20        k       False       1
# 21        l        True      55
# 22        l       False       1
# 23        m        True      95
# 24        m       False       3
# 25        n        True      32
# 26        n       False       1
# 27        o        True     128
# 28        o       False       5
# 29        p        True      62
# 30        p       False       7
# 31        q        True       7
# 32        r        True      46
# 33        r       False       3
# 34        s        True     190
# 35        s       False       3
# 36        t        True     103
# 37        t       False      11
# 38        u        True      18
# 39        v        True     197
# 40        v       False      12
# 41        w        True      57
# 42        w       False       1
# 43        x        True       4
# 44        y        True       9
# 45        y       False       1
# 46        z        True      24

# %%
color_scale = alt.Scale(
            domain=[False, True],
            range=["#e23b3b", "#8dc456"]
        )

chart = alt.Chart(x).mark_bar().encode(
    x='alphabet',
    y='counts',
    color=alt.Color(
        'correction',
        scale = color_scale,
    ))
chart
# Out:
# <VegaLite 2 object>

# %% [markdown]
# Since some starting letters occur more frequently than others, it is advisable to calculate the relative percentages for each letter. E.g. for the letter 'a', the syllabifier has a score of 93.94% of correct predictions.

# %%
x_percentages = df.groupby('alphabet').correction.value_counts('True', 'False').to_frame()
x_percentages.columns = ['counts']
x_percentages = x_percentages.reset_index()
x_percentages
# Out:
#    alphabet  correction    counts
# 0         a        True  0.939394
# 1         a       False  0.060606
# 2         b        True  0.978102
# 3         b       False  0.021898
# 4         c        True  0.918182
# 5         c       False  0.081818
# 6         d        True  0.938596
# 7         d       False  0.061404
# 8         e        True  0.960000
# 9         e       False  0.040000
# 10        f        True  1.000000
# 11        g        True  0.966102
# 12        g       False  0.033898
# 13        h        True  0.965909
# 14        h       False  0.034091
# 15        i        True  0.904762
# 16        i       False  0.095238
# 17        j        True  0.909091
# 18        j       False  0.090909
# 19        k        True  0.968750
# 20        k       False  0.031250
# 21        l        True  0.982143
# 22        l       False  0.017857
# 23        m        True  0.969388
# 24        m       False  0.030612
# 25        n        True  0.969697
# 26        n       False  0.030303
# 27        o        True  0.962406
# 28        o       False  0.037594
# 29        p        True  0.898551
# 30        p       False  0.101449
# 31        q        True  1.000000
# 32        r        True  0.938776
# 33        r       False  0.061224
# 34        s        True  0.984456
# 35        s       False  0.015544
# 36        t        True  0.903509
# 37        t       False  0.096491
# 38        u        True  1.000000
# 39        v        True  0.942584
# 40        v       False  0.057416
# 41        w        True  0.982759
# 42        w       False  0.017241
# 43        x        True  1.000000
# 44        y        True  0.900000
# 45        y       False  0.100000
# 46        z        True  1.000000

# %%
color_scale = alt.Scale(
            domain=[False, True],
            range=["#e23b3b", "#8dc456"]
        )

chart = alt.Chart(x_percentages).mark_bar().encode(
    x='alphabet',
    y='counts',
    color=alt.Color(
        'correction',
        scale = color_scale,
    ))
chart
# Out:
# <VegaLite 2 object>

# %% [markdown]
# Below, we list all the mistakes made by the syllabifier, along with their respective manual correction.
# Some of the things that the model still has to learn are:
# * A single *-s-* or *-t-* can never be a syllable.
# * For Latin names, the ending *-ius* has to be split up into two syllables.
# * The ending *-ien* to mark plurals (today: *-iën*), has to be split up into two syllables. We know this because in Middle Dutch rhymed texts, *abdien* rhymes with *vrijen*, *partien*, *lijen*, *marien*, *prophetien*, etc.
# **In Bouma & Hermans' training material, this is not the case! This needs to be corected. **

# %%
x = df.set_index('correction')
mistakes = x.loc[False]
mistakes
# Out:
#                       word        syllabifier manual_syllabification alphabet
# correction
# False            absolutie        ab-solu-tie           ab-so-lu-tie        a
# False         aertsebiscop   aert-se-bi-s-cop        aert-se-bis-cop        a
# False                 amye              a-mye                 a-my-e        a
# False            anchanius        an-cha-nius           an-cha-ni-us        a
# False              aneblic           a-neblic              a-ne-blic        a
# False              arrianc           ar-rianc              ar-ri-anc        a
# False            besmettet       be-s-met-tet            be-smet-tet        b
# False              blavyen           bla-vyen              bla-vy-en        b
# False              bolyoen           boly-oen              bo-ly-oen        b
# False               caldea            cal-dea               cal-de-a        c
# False           capedocien      ca-pe-do-cien         ca-pe-do-ci-en        c
# False            claradijs         clara-dijs            cla-ra-dijs        c
# False           cleopatren       cleop-at-ren          cle-op-at-ren        c
# False            cleopolis        cleo-po-lis           cle-o-po-lis        c
# False             corosaen        co-ro-s-aen             co-ro-saen        c
# False           crisoliten     cri-s-o-li-ten          cri-so-li-ten        c
# False           crisolitus     cri-s-o-li-tus          cri-so-li-tus        c
# False                curus              curus                 cu-rus        c
# False              daciane           da-ciane             da-ci-a-ne        d
# False           delachtich      de-l-ach-tich           del-ach-tich        d
# False             demophon          de-mophon             de-mo-phon        d
# False         desideriumme   de-si-de-rium-me      de-si-de-ri-um-me        d
# False           destrueren       des-true-ren          des-tru-e-ren        d
# False               drians             drians                dri-ans        d
# False          dyocletiaen      dyocle-ti-aen        dy-o-cle-ti-aen        d
# False         ecclesiastes    ecc-le-sias-tes       ecc-le-si-as-tes        e
# False       ertschenbiscop  ertschen-bi-s-cop      ert-schen-bis-cop        e
# False           gascoenien       gas-coe-nien          gas-coe-ni-en        g
# False          geacordeert      ge-acor-deert         ge-a-cor-deert        g
# False         gedisponeert     ge-dis-poneert        ge-dis-po-neert        g
# ...                    ...                ...                    ...      ...
# False                rgave            r-ga-ve                 rga-ve        r
# False                riote             rio-te                ri-o-te        r
# False            siecheide         siechei-de            siec-hei-de        s
# False               siestu             siestu                sies-tu        s
# False          substancien      sub-stan-cien         sub-stan-ci-en        s
# False           taureliane      tau-re-lia-ne         tau-re-li-a-ne        t
# False              tgewoen          t-ge-woen               tge-woen        t
# False             tghewelt         t-ghe-welt              tghe-welt        t
# False              thanaym           tha-naym              tha-na-ym        t
# False           theodocius       the-odo-cius         the-o-do-ci-us        t
# False            toegehort       toe-g-e-hort            toe-ge-hort        t
# False           toespreken       toes-pre-ken           toe-spre-ken        t
# False             trisorie        tri-s-o-rie             tri-so-rie        t
# False           tsertoghen      t-ser-to-ghen           tser-to-ghen        t
# False            tverclaer        t-verc-laer             tver-claer        t
# False            tweewaerf        twee-w-aerf             twee-waerf        t
# False         verandwerden    ve-rand-wer-den        ver-and-wer-den        v
# False            vertrecte       ver-t-rec-te            ver-trec-te        v
# False         vertroestene   ver-t-roes-te-ne        ver-troes-te-ne        v
# False             vervroie         ver-v-roie             ver-vro-ie        v
# False               viande            vian-de               vi-an-de        v
# False             vischere          vische-re             vi-sche-re        v
# False              viviane          vi-via-ne             vi-vi-a-ne        v
# False           vliticheit      vli-ti-c-heit           vli-ti-cheit        v
# False                vraie              vraie                 vra-ie        v
# False           vreemthede       vreem-the-de           vreemt-he-de        v
# False                vrien              vrien                 vri-en        v
# False          vuulicheden      vuu-liche-den         vuu-lic-he-den        v
# False               ysayam            y-sayam               y-sa-yam        y
# False             wteghinc          wte-ghinc             w-te-ghinc        w
#
# [91 rows x 4 columns]

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
